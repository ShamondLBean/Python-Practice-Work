# %%
#Programming Exercise Q.2 Car Class
#First I will start with making the class for the car
class Car:
    #Next I will use the init method 
    def __init__(self, year_model, make, speed):
        self.___year_model = year_model
        self.__make = make
        self.__speed = speed
#Next I will set the year for the car
    def set_year_model(self, year_model):
        self.___year_model = year_model
#Next I will set the make of the car
    def set_make(self, make):
        self.__make = make
#Next I will return the year of the car
    def get_year_model(self):
        return self.___year_model
#Next I will return the make of the car
    def get_make(self):
        return self.__make
#Next I will make a variable for the speed of the car
    def set_speed(self, speed):
        self.__speed = speed
#Next I will give the car the ability to accelerate
    def accelerate(self): 
        self.__speed += 5
#Next I will give the car the ability to brake as well
    def brake(self):
        self.__speed -= 5
#Next I will return the speed of the car
    def get_speed(self):
        return self.__speed
def main():
#Next I will set the year, make, and speed of the car
    my_car = Car(2014, 'Toyota', 70)
    my_car.set_speed(0)
#Next I will set the range for the car to accelerate or brake 5 times
    for i in range(5):
        my_car.accelerate()
        print('The current speed of the car is:', my_car.get_speed())
    print()
    for j in range(5):
        my_car.brake()
        print('The current speed of the car is:', my_car.get_speed())
main()
#This was the problem I decided to record since I figured it'd be the easier out of the two. It's my first time recording
#myself coding so I was a bit nervous, I was able to get through it without much problem besides typos and trying to set my
#Returns to early!
# Out:
# The current speed of the car is: 5
# The current speed of the car is: 10
# The current speed of the car is: 15
# The current speed of the car is: 20
# The current speed of the car is: 25
#
# The current speed of the car is: 20
# The current speed of the car is: 15
# The current speed of the car is: 10
# The current speed of the car is: 5
# The current speed of the car is: 0

# %%
#Programming Exercise Q.5 Retail Item Class
#I will start by setting the class of RetailItem
class RetailItem:
    #Next I will use init for the description, units, and price
    def __init__(self, description, units_in_inventory, price):
        self.__descrip = description
        self.__inv = units_in_inventory
        self.__price = price
#Next I will set the description
    def set_description(self, description):
        self.__descrip = description
#Next I will set the units
    def set_units_in_inventory(self, units_in_inventory):
        self.__inv = units_in_inventory
#Next I will set the price
    def set_price(self, price):
        self.__price = price
#Next I will return the description
    def get_description(self):
        return self.__descrip
#Next I will return the units
    def get_units_in_inventory(self):
        return self.__inv
#Next I will return the price
    def get_price(self):
        return self.__price
#Next I will define the str method to return the objects
    def __str__(self):
        return 'description: ' + self.__descrip + '\n' \
        'units in inventory: ' + str(self.__inv) + '\n' \
        'price: ' + str(self.__price)
def main():
#Next I will describe the retail items
    item1 = RetailItem('Moncler Bubble Coat', 23, 1129.99)
    item2 = RetailItem('Purple Jeans', 7, 249.99)
    item3 = RetailItem('Gallery Dept Shirt', 9, 499.99)
#Next I will print the details for each item    
    print('Here are the details for each item:')
    print('=================================')
    print()
#Next I will print the details for each item individually
    print('Item 1')
    print('------')
    print(item1)
    print()
    print('Item 2')
    print('------')
    print(item2)
    print()
    print('Item 3')
    print('------')
    print(item3)
    print()
#Lastly I will call main to run the program
main()
# Out:
# Here are the details for each item:
# ...
#
# Item 1
# ------
# description: Moncler Bubble Coat
# units in inventory: 23
# price: 1129.99
#
# Item 2
# ------
# description: Purple Jeans
# units in inventory: 7
# price: 249.99
#
# Item 3
# ------
# description: Gallery Dept Shirt
# units in inventory: 9
# price: 499.99
